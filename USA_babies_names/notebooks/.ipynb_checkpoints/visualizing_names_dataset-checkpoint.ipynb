# %% [markdown]
# ###  Visualize the Names Dataset

# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
print(plt.style.available) #all the avilable themes
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df_emily = pd.read_csv('../data/female_emilys_only.csv')

# %%
#using the theme from  availble above
plt.style.use('seaborn-v0_8-dark-palette')

# %%
# df_emily.plot(x='year', y='frequency')

# %% [markdown]
# #### Create a plot of the summed up frequency (total births) per year from 1880 to 2020.

# %%
# births_dict = {'year':[], 'total_births':[]}

# %%
#parse function
def parse_dataset(year):
    
    path = f'../data/yob{year}.txt'
    df = pd.read_csv(path, names = ['name','gender','frequency'])
#     df["year"] = year
    return df

# %%
#Loop over the years from 1880 to 2020
births_dict = {'year':[], 'total_births':[]}
for year in range(1880, 2023):
    df = parse_dataset(year)
    sum_F = df['frequency'].sum()
    
    births_dict['total_births'].append(sum_F)
    births_dict['year'].append(year)

yearly_births = pd.DataFrame(births_dict)

# %%
yearly_births
# Out:
#      year  total_births
# 0    1880        201484
# 1    1881        192690
# 2    1882        221533
# 3    1883        216945
# 4    1884        243461
# ..    ...           ...
# 138  2018       3511750
# 139  2019       3465821
# 140  2020       3333981
# 141  2021       3379713
# 142  2022       3361896
#
# [143 rows x 2 columns]

# %%
pwd

# %% [markdown]
# #### Plotting

# %%
# yearly_births
plt.plot(yearly_births['year'], yearly_births['total_births'],label = ['all years'])
plt.title('Total Births by Years')
plt.ylabel('Total Births')
plt.xlabel('Years')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ####  Visualize the Distribution of Names

# %% [markdown]
# - Read in a single dataset for one year using the parse_dataset() function and create a histogram of the frequency column.
# - The distribution is highly skewed! Include the following log=True in plt.hist to improve the visualization!
# - Play around with the number of bins bins to make the visualization even clearer.
# - Do the same for another year and compare the two distributions with each other.
# - Add labels and a title

# %%
df_1999 = parse_dataset(1999)

# %%
df_1999
# Out:
#            name gender  frequency
# 0         Emily      F      26539
# 1        Hannah      F      21678
# 2        Alexis      F      19235
# 3         Sarah      F      19115
# 4      Samantha      F      19041
# ...         ...    ...        ...
# 28552     Zyier      M          5
# 28553    Zyquan      M          5
# 28554    Zyquez      M          5
# 28555     Zyron      M          5
# 28556   Zyshaun      M          5
#
# [28557 rows x 3 columns]

# %%
plt.hist(df_1999['frequency'],
         bins=[30,60,90,120,150,180,210,240,270,300,330,365],
         label = 'Frequencies',
         edgecolor = 'k',
         alpha = 0.7,
         log=False)
plt.title('Frequency of Names in 1999')
plt.ylabel('Frequency')
plt.xlabel('Years')
plt.legend()
plt.show()

# %%
df_2010 = parse_dataset(2010)
df
# Out:
#             name gender  frequency
# 0         Olivia      F      16573
# 1           Emma      F      14435
# 2      Charlotte      F      12891
# 3         Amelia      F      12333
# 4         Sophia      F      12310
# ...          ...    ...        ...
# 31910     Zuberi      M          5
# 31911       Zydn      M          5
# 31912      Zylon      M          5
# 31913     Zymeer      M          5
# 31914    Zymeire      M          5
#
# [31915 rows x 3 columns]

# %%
plt.hist(df_2010['frequency'],
         bins=[30,60,90,120,150,180,210,240,270,300,330,365],
         label = 'Frequencies',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.title('Frequency of Names in 2010')
plt.ylabel('Frequency')
# plt.xlabel('Years')
plt.legend()
plt.show()

# %%
plt.hist(df_2010['frequency'],
         bins=[30,60,90,120,150,180,210,240,270,300,330,365],
         label = '2010',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.hist(df_1999['frequency'],
         bins=[30,60,90,120,150,180,210,240,270,300,330,365],
         label = '1999',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.title('Comparison of Frequencies for 1999 & 2010')
plt.ylabel('Frequency')
# plt.xlabel('Years')
plt.legend()
plt.show()

# %%
# plt.hist(df_2010['frequency'],
#          bins=[30,60,90,120,150,180,210,240,270,300,330,365],
#          label = '2010',
#          edgecolor = 'k',
#          alpha = 0.7,
#          log=True)
plt.hist([df_1999['frequency'],df_2010['frequency']],
         bins=[30,60,90,120,150,180,210,240,270,300,330,365],
#          labels = ['1999','2010']
#          edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.title('Comparison of Frequencies for 1999 & 2010')
plt.ylabel('Frequency')
# plt.xlabel('Years')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ###  Number of unique names over time

# %% [markdown]
# - How has the number of unique names given to newborn children varied over time?
# - For each year from 1880 til 2020
#      - read in the data using the parse_dataset() function
#      - use nunique() to count the unique names for each year
#      - keep track of the year and the count in a dictionary
#      - convert dictionary to pandasDataFrame as was done in the first milestone for this lesson
# - Visualize the data, use the years on the x-axis and the counts on the y-axis.

# %%
unique_names = {'name':[]}

for year in range(1880, 2023):
    df_year = parse_dataset(year) 
    unique_names_count = len(df_year['name'].unique()) #used len() to solve ValueError: setting an array element with a sequence"
    unique_names['name'].append(unique_names_count) 


unique_names = pd.DataFrame(unique_names)

# %%
plt.plot(range(1880,2023),
         unique_names['name'], 
         label = 'Number of unique names')
plt.title('Unique Names Given to Newborn Children over Time')
plt.ylabel('Count')
plt.xlabel('Year')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Track a name over time

# %% [markdown]
# - Using any of the single name over time dataframes created in Filtering DataFrames
# - Create a line plot with the years and the (relative) frequencies of a specific name

# %%
df_emily = pd.read_csv('../data/female_emilys_only.csv')
df_emily
# Out:
#      Unnamed: 0   name gender  frequency    year
# 0            99  Emily      F        210  1880.0
# 1          2089  Emily      F        244  1881.0
# 2          4028  Emily      F        272  1882.0
# 3          6141  Emily      F        342  1883.0
# 4          8225  Emily      F        364  1884.0
# ..          ...    ...    ...        ...     ...
# 138     1925722  Emily      F       8706  2018.0
# 139     1957943  Emily      F       8248  2019.0
# 140     1990058  Emily      F       6908  2020.0
# 141     2021578  Emily      F       6577  2021.0
# 142     2053259  Emily      F       6461  2022.0
#
# [143 rows x 5 columns]

# %%
freq = df_emily['frequency']
relative_freq = (freq) / (freq).sum()

# %%
plt.style.use('seaborn-v0_8-dark-palette')
plt.plot(df_emily['year'],
              relative_freq,
             label= 'Emily')
plt.title('Relative Frequencies of Emily')
plt.ylabel('Frequency')
plt.xlabel('Years')
plt.grid(True)
plt.legend()
plt.show()

# %%
### tyrion lannister - got 2011-2019

df_tyrion = pd.read_csv('../data/tyrions_only.csv')

freq = df_tyrion['frequency']
relative_freq = (freq) / (freq).sum()

plt.style.use('seaborn-v0_8-dark-palette')
plt.plot(df_tyrion ['year'],
         relative_freq,
         label= 'Tyrion')
plt.plot(df_tyrion['year'][15], 
         relative_freq[15], 
         marker='h', markersize= '7', markerfacecolor = 'red' )

# max_value = max(relative_freq)

# max_index = relative_freq.idxmax()

# # Annotate the maximum value on the plot
# plt.annotate(f'Max: {max_value}', xy=(df_tyrion['year'][max_index], max_value), xytext=(10, -20),
#              textcoords='offset points', arrowprops=dict(arrowstyle="->"))

plt.title('')
plt.ylabel('Frequency')
plt.xlabel('Years')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ###  Analyze the length of names

# %% [markdown]
# - Plot the distribution of the length of each name for a given year
# - Does the distribution change over time?
# - Plot the average length of names over time!

# %%
    df_2000 = parse_dataset(2000)  
    df_2000['name_length'] = df_2000['name'].apply(lambda x: len(x))
    df_2000
# Out:
#           name gender  frequency  name_length
# 0        Emily      F      25957            5
# 1       Hannah      F      23085            6
# 2      Madison      F      19968            7
# 3       Ashley      F      17998            6
# 4        Sarah      F      17712            5
# ...        ...    ...        ...          ...
# 29771     Zeph      M          5            4
# 29772    Zeven      M          5            5
# 29773    Ziggy      M          5            5
# 29774       Zo      M          5            2
# 29775    Zyier      M          5            5
#
# [29776 rows x 4 columns]

# %%
plt.hist(df_2000['name_length'], 
          bins=20,
         label = '2000',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.title('Length of Names in 2000')
plt.ylabel('Length')

plt.legend()
plt.show()

# %%
df_2010 = parse_dataset(2010)
df_2010['name_length'] = df_2010['name'].apply(lambda x: len(x))
# df_2010

plt.hist(df_2010['name_length'], 
          bins=20,
         label = '2010',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.title('Length of Names in 2010')
plt.ylabel('Length')

plt.legend()
plt.show()

# %%
#comparison hist plot
plt.hist(df_2000['name_length'], 
          bins=20,
         label = '2000',
         color = 'orange',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
# plt.hist(df_2010['name_length'], 
#           bins=20,
#          label = '2010',
#          edgecolor = 'k',
#          alpha = 0.7,
#          log=True)

plt.hist(df_2021['name_length'], 
          bins=20,
         label = '2021',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)

plt.title('Comparison of Length of Names over years')
plt.ylabel('Length')
plt.legend()
plt.show()

# %%
#comparison plot

plt.plot(df_2000['name_length'], 
         label = '2000',
         color = 'orange',
         alpha = 0.7)
plt.xlim(0,10)
# plt.plot(df_2010['name_length'], 
#          label = '2010',
#          alpha = 0.7)
plt.xlim(0,10)
plt.plot(df_2021['name_length'], 
         label = '2021',
         alpha = 0.7)
plt.xlim(0,10)
plt.title('Comparison of Length of Names over years')
plt.ylabel('Length')
plt.legend()
plt.show()

# %%
df_2021 = parse_dataset(2021)
df_2021['name_length'] = df_2021['name'].apply(lambda x: len(x))
# df_2010

plt.hist(df_2021['name_length'], 
          bins=20,
         label = '2021',
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
plt.title('Length of Names in 2021')
plt.ylabel('Length')

plt.legend()
plt.show()

# %%
#function for distribution of name length over year

def name_length_dis(year):
    df_year = parse_dataset(year)
    df_year['name_length'] = df_year['name'].apply(lambda x: len(x))
    
    plt.hist(df_year['name_length'], 
          bins=20,
         label = year,
         edgecolor = 'k',
         alpha = 0.7,
         log=True)
    plt.title('Length of Names over year')
    plt.ylabel('Length')
    plt.legend()
    plt.show()

    return

# %%
name_length_dis(2021)

# %%
avg_name_lengths = {'year': [], 'avg_name_length': []}

for year in range(1880, 2023):
    df_year = parse_dataset(year)
    name_length = df_year['name'].apply(lambda x: len(x))
    avg_name_length = name_length.mean()
    avg_name_lengths['year'].append(year)
    avg_name_lengths['avg_name_length'].append(avg_name_length)


df_avg_name_length = pd.DataFrame(avg_name_lengths)

df_avg_name_length
# Out:
#      year  avg_name_length
# 0    1880         5.700000
# 1    1881         5.673733
# 2    1882         5.724024
# 3    1883         5.697217
# 4    1884         5.716152
# ..    ...              ...
# 138  2018         6.123243
# 139  2019         6.104612
# 140  2020         6.070311
# 141  2021         6.064384
# 142  2022         6.052107
#
# [143 rows x 2 columns]

# %%
plt.plot(df_avg_name_length['year'], df_avg_name_length['avg_name_length'], label = 'Average name length')
plt.title('Average Length of Names Over Time')
plt.xlabel('Year')
plt.ylabel('Length')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### identify naming patterns specific to different generations, such as Baby Boomers, Generation X, Millennials, and Generation Z

# %%
df_year
# Out:
#            name gender  frequency
# 0          Mary      F       7065
# 1          Anna      F       2604
# 2          Emma      F       2003
# 3     Elizabeth      F       1939
# 4        Minnie      F       1746
# ...         ...    ...        ...
# 1995     Woodie      M          5
# 1996     Worthy      M          5
# 1997     Wright      M          5
# 1998       York      M          5
# 1999  Zachariah      M          5
#
# [2000 rows x 3 columns]
