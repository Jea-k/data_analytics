# %% [markdown]
# ### Make a high quality plot

# %%
# %matplotlib inline
# !pip install --upgrade matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 1
# Open empty jupyter notebook and read in the dataframe that contains your gapminder data

# %%
df = pd.read_csv('../data/gapminder_total.csv')

# %%
df
# Out:
#            country  year  life expectancy continent  population  fertility
# 0      Afghanistan  1951            27.13      Asia   7839426.0       7.67
# 1      Afghanistan  1952            27.67      Asia   7934798.0       7.67
# 2      Afghanistan  1953            28.19      Asia   8038312.0       7.67
# 3      Afghanistan  1954            28.73      Asia   8150037.0       7.67
# 4      Afghanistan  1955            29.27      Asia   8270024.0       7.67
# ...            ...   ...              ...       ...         ...        ...
# 10915     Zimbabwe  2011            51.60    Africa  14255592.0       3.64
# 10916     Zimbabwe  2012            54.20    Africa  14565482.0       3.56
# 10917     Zimbabwe  2013            55.70    Africa  14898092.0       3.49
# 10918     Zimbabwe  2014            57.00    Africa  15245855.0       3.41
# 10919     Zimbabwe  2015            59.30    Africa  15602751.0       3.35
#
# [10920 rows x 6 columns]

# %% [markdown]
# ### Step 2
# Create subset of data for one year

# %%
df_subset = df[df['year'] == 2000]

# %%
df_subset
# Out:
#                    country  year  life expectancy      continent  population  \
# 49             Afghanistan  2000             50.1           Asia  19701940.0
# 114                Albania  2000             74.7         Europe   3121965.0
# 179                Algeria  2000             73.3         Africa  31183658.0
# 244                 Angola  2000             52.3         Africa  15058638.0
# 309    Antigua and Barbuda  2000             73.8  North America     77648.0
# ...                    ...   ...              ...            ...         ...
# 10644            Venezuela  2000             73.8  South America  24481477.0
# 10709              Vietnam  2000             72.0           Asia  80285563.0
# 10774                Yemen  2000             62.4           Asia  17795219.0
# 10839               Zambia  2000             44.8         Africa  10585220.0
# 10904             Zimbabwe  2000             47.9         Africa  12499981.0
#
#        fertility
# 49          7.73
# ...

# %% [markdown]
# ### Step 4
# Plot the life expectancy vs fertility rate

# %%
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='country',
            legend= False);

# %% [markdown]
# ### Step 5
# Using matplotlib add a title and labels. Increase the plot size to make it more readable.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent', 
            legend= 'brief');
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel('Fertility')
plt.xlabel('Life Expectancy');

# %% [markdown]
# ### Step 6
# Weight the size of the scatter points to the population of each country. This can be done using the size parameter in the sns.scatterplot() function.
#
# Tip: the code above is correct but the magnitude of the population is astronomically larger than that of the life expectancy and fertility rate. Use some math to fix this.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent',
            size= df_subset['population']/100000,
            sizes=(50, 600)
               )
plt.legend(scatterpoints=1, frameon=False, labelspacing=0.8)
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel('Fertility')
plt.xlabel('Life Expectancy');

# %% [markdown]
# ### Step 7
# Setting the axes to display the origin also gives us a more complete picture of what is going on.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent',
            size= df_subset['population']/100000,
            sizes=(50, 600)
               )
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel('Fertility')
plt.xlabel('Life Expectancy')
plt.axis([0, 85, 0, 9.5]);

# %%
sns.set_style("darkgrid") # setting the style
plt.subplots(figsize=(8,6))
# plt.figure(figsize=(8,5))
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent',
            size= df_subset['population']/100000,
            sizes=(50, 600)
               )
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel('Fertility')
plt.xlabel('Life Expectancy')
plt.axis([0, 85, 0, 9.5]);

# %%
graph = sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent',
            size= df_subset['population']/100000,
            sizes=(50, 600),
#             style= 'continent'
               )

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent',
            size= df_subset['population']/100000,
            sizes=(50, 600),
#             style= 'continent'
               )

handles,labels = graph.get_legend_handles_labels()
plt.legend(handles[0:7],labels[0:7], loc='lower left', borderaxespad=0.5, fontsize=12)
handles, labels

plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel('Fertility')
plt.xlabel('Life Expectancy')
plt.axis([0, 85, 0, 9.5]);

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_subset,
            x='life expectancy', 
            y='fertility',
            hue='continent',
            size= df_subset['population']/100000,
            sizes=(50, 600),
#             style= 'continent'
               )
handles,labels = graph.get_legend_handles_labels()
plt.legend(handles[0:7],labels[0:7], loc='lower left', borderaxespad=0.5, fontsize=12)
handles,labels

#Add labels and title
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel('Fertility')
plt.xlabel('Life Expectancy')
plt.axis([0, 85, 0, 9.5]);

# Add label markers for specific countries
countries_to_label = ['Pakistan', 'Germany', 'China']
for country in countries_to_label:
    x = float(df_subset.loc[df_subset['country'] == country, 'life expectancy'].iloc[0])
    y = float(df_subset.loc[df_subset['country'] == country, 'fertility'].iloc[0])
    plt.text(x, y, country, fontsize=8, ha='center', va='center');

#save the plot
plt.savefig('../scatterplots/plot_2000.png',dpi=300,format='png')

# %%
def gapminder_plot(year):
    plt.figure(figsize=(8, 5), edgecolor='black')
    sns.set_style("darkgrid")
    
    # Filter the data for the current year
    df_year = df[df['year'] == year]
    
    # Creating scatter plot
    sns.scatterplot(data=df_year,
                    x='life expectancy',
                    y='fertility',
                    hue='continent',
                    size=df_year['population'] / 100000,
                    sizes=(50, 600),
                    alpha=0.8,
                    linewidths=200,  # Adjust the value to create more separation
                    )
    plt.xticks(rotation=45)
    plt.axis([0, 85, 0, 9.5])

    # Editing the legend
    handles, labels = plt.gca().get_legend_handles_labels()
    plt.legend(handles[0:7], labels[0:7], borderaxespad=0.7, fontsize=8, bbox_to_anchor=(1.4, 1))
    
    # Add labels and title
    plt.title('Life Expectancy vs Fertility Rate')
    plt.ylabel('Fertility')
    plt.xlabel('Life Expectancy')

    # Add label markers for specific countries
    countries_to_label = ['Pakistan', 'Germany', 'China', 'United States']
    for country in countries_to_label:
        x = float(df_year.loc[df_year['country'] == country, 'life expectancy'].values[0])
        y = float(df_year.loc[df_year['country'] == country, 'fertility'].values[0])
        plt.text(x, y, country, fontsize=8, ha='center', va='center')

    # Add year label
    plt.text(20, 9, f'Year: {year}', fontsize=8, ha='right', va='top', 
             bbox= dict(facecolor='whitesmoke', boxstyle='round,pad=0.5'))
    
   #editing the spine or the edge of the graph 
    for spine in plt.gca().spines.values():
        spine.set_visible(True)
        spine.set_linewidth(0.5)
        spine.set_color('gray')
    
    plt.tight_layout()
    plt.savefig(f'../scatterplots/plot_{year}.png', dpi=300)

# %%
#call the function
gapminder_plot(2015)
