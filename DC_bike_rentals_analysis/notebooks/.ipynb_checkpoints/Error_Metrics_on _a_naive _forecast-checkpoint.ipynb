# %% [markdown]
# ## Error Metrics on a naive forecast

# %% [markdown]
# With regard to the bikes dataset a ’naive’ forecast would be to use the count from the year before to predict the next year. Use the count from May 2011 as a forecast for May 2012 and check how far off the predictions are:
#
# 1. Filter the dataset for May 2011 and the count column
# 2. Filter the dataset for May 2012 and the count column
# 3. Use the above results as the input for rmse
# 4. How far off on average was this naive prediction?
#
# ### Bonus:
#
# How could the results be improved?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import statsmodels.tools.eval_measures as sm

# %%
df = pd.read_csv('../data/bike_dataset_new.csv',parse_dates=['datetime'])

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 17374 2012-12-31 19:00:00       1        0           1        2  10.66
# 17375 2012-12-31 20:00:00       1        0           1        2  10.66
# 17376 2012-12-31 21:00:00       1        0           1        1  10.66
# 17377 2012-12-31 22:00:00       1        0           1        1  10.66
# 17378 2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count  hour  month  \
# 0      14.395        81     0.0000     3.0        13.0     16     0      1
# 1      13.635        80     0.0000     8.0        32.0     40     1      1
# 2      13.635        80     0.0000     5.0        27.0     32     2      1
# 3      14.395        75     0.0000     3.0        10.0     13     3      1
# 4      14.395        75     0.0000     0.0         1.0      1     4      1
# ...       ...       ...        ...     ...         ...    ...   ...    ...
# 17374  12.880        60    11.0014     NaN         NaN    156    19     12
# 17375  12.880        60    11.0014     NaN         NaN    104    20     12
# 17376  12.880        60    11.0014     NaN         NaN     67    21     12
# 17377  13.635        56     8.9981     NaN         NaN     43    22     12
# 17378  13.635        65     8.9981     NaN         NaN     28    23     12
#
#        weekday  day  year part_of_day
# 0            5    1  2011     morning
# 1            5    1  2011     morning
# 2            5    1  2011     morning
# 3            5    1  2011     morning
# 4            5    1  2011     morning
# ...        ...  ...   ...         ...
# 17374        0   31  2012     evening
# 17375        0   31  2012     evening
# 17376        0   31  2012       night
# 17377        0   31  2012       night
# 17378        0   31  2012       night
#
# [17379 rows x 18 columns]

# %%
df_may_2011 = df[(df['year'] == 2011) & (df['month'] == 5)]
df_may_2011
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 2786 2011-05-01 00:00:00       2        0           0        1  17.22  21.210
# 2787 2011-05-01 01:00:00       2        0           0        1  17.22  21.210
# 2788 2011-05-01 02:00:00       2        0           0        1  17.22  21.210
# 2789 2011-05-01 03:00:00       2        0           0        1  16.40  20.455
# 2790 2011-05-01 04:00:00       2        0           0        1  16.40  20.455
# ...                  ...     ...      ...         ...      ...    ...     ...
# 3525 2011-05-31 19:00:00       2        0           1        1  31.98  37.120
# 3526 2011-05-31 20:00:00       2        0           1        1  31.98  37.120
# 3527 2011-05-31 21:00:00       2        0           1        1  31.16  36.365
# 3528 2011-05-31 22:00:00       2        0           1        1  30.34  34.850
# 3529 2011-05-31 23:00:00       2        0           1        1  29.52  34.850
#
#       humidity  windspeed  casual  registered  count  hour  month  weekday  \
# 2786        67     6.0032    19.0        77.0     96     0      5        6
# 2787        69     7.0015     9.0        50.0     59     1      5        6
# 2788        77     7.0015     7.0        43.0     50     2      5        6
# 2789        82     7.0015     8.0        15.0     23     3      5        6
# 2790        76     7.0015     6.0        11.0     17     4      5        6
# ...        ...        ...     ...         ...    ...   ...    ...      ...
# 3525        62     7.0015     NaN         NaN    407    19      5        1
# 3526        62     7.0015     NaN         NaN    310    20      5        1
# 3527        66     7.0015     NaN         NaN    224    21      5        1
# 3528        70    11.0014     NaN         NaN    160    22      5        1
# 3529        79     6.0032     NaN         NaN     98    23      5        1
#
#       day  year part_of_day
# 2786    1  2011     morning
# 2787    1  2011     morning
# 2788    1  2011     morning
# 2789    1  2011     morning
# 2790    1  2011     morning
# ...   ...   ...         ...
# 3525   31  2011     evening
# 3526   31  2011     evening
# 3527   31  2011       night
# 3528   31  2011       night
# 3529   31  2011       night
#
# [744 rows x 18 columns]

# %%
count_2011 = df_may_2011['count']
count_2011
# Out:
# 2786     96
# 2787     59
# 2788     50
# 2789     23
# 2790     17
#        ...
# 3525    407
# 3526    310
# 3527    224
# 3528    160
# 3529     98
# Name: count, Length: 744, dtype: int64

# %%
df_may_2012 = df[(df['year'] == 2012) & (df['month'] == 5)]
df_may_2012
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 11539 2012-05-01 00:00:00       2        0           1        2  20.50
# 11540 2012-05-01 01:00:00       2        0           1        2  20.50
# 11541 2012-05-01 02:00:00       2        0           1        2  20.50
# 11542 2012-05-01 03:00:00       2        0           1        2  20.50
# 11543 2012-05-01 04:00:00       2        0           1        2  21.32
# ...                   ...     ...      ...         ...      ...    ...
# 12278 2012-05-31 19:00:00       2        0           1        1  29.52
# 12279 2012-05-31 20:00:00       2        0           1        1  27.88
# 12280 2012-05-31 21:00:00       2        0           1        1  27.88
# 12281 2012-05-31 22:00:00       2        0           1        1  27.06
# 12282 2012-05-31 23:00:00       2        0           1        1  27.06
#
#         atemp  humidity  windspeed  casual  registered  count  hour  month  \
# 11539  24.240        59    12.9980     7.0        28.0     35     0      5
# 11540  24.240        63     8.9981     0.0        21.0     21     1      5
# 11541  24.240        72     6.0032     1.0         7.0      8     2      5
# 11542  24.240        77     0.0000     1.0         2.0      3     3      5
# 11543  25.000        72     6.0032     1.0         7.0      8     4      5
# ...       ...       ...        ...     ...         ...    ...   ...    ...
# 12278  32.575        34    11.0014     NaN         NaN    420    19      5
# 12279  31.820        44    11.0014     NaN         NaN    336    20      5
# 12280  31.820        44    11.0014     NaN         NaN    249    21      5
# 12281  31.060        50    11.0014     NaN         NaN    188    22      5
# 12282  31.060        54    15.0013     NaN         NaN    135    23      5
#
#        weekday  day  year part_of_day
# 11539        1    1  2012     morning
# 11540        1    1  2012     morning
# 11541        1    1  2012     morning
# 11542        1    1  2012     morning
# 11543        1    1  2012     morning
# ...        ...  ...   ...         ...
# 12278        3   31  2012     evening
# 12279        3   31  2012     evening
# 12280        3   31  2012       night
# 12281        3   31  2012       night
# 12282        3   31  2012       night
#
# [744 rows x 18 columns]

# %%
count_2012 = df_may_2012['count']
count_2012
# Out:
# 11539     35
# 11540     21
# 11541      8
# 11542      3
# 11543      8
#         ...
# 12278    420
# 12279    336
# 12280    249
# 12281    188
# 12282    135
# Name: count, Length: 744, dtype: int64

# %%
# sns.heatmap(data=df_may_2011,
#                 x='month',y='count')

# sns.barplot(data=df_may_2012,
#                 x='month',y='count');

# %%
count_2011.mean() , count_2012.mean()
# Out:
# (202.3252688172043, 252.5766129032258)

# %%
rmse = sm.rmse(count_2011, count_2012)
rmse
# Out:
# 168.69935321213757

# %% [markdown]
# rmse value shows how far off, on average, the naive prediction was from the actual values. In this case, the average difference between prediction and the actual values is about 168.7

# %% [markdown]
# To improve the prediction accuracy, we can consider other factors that affect bike rentals, such as seasonality, trends, holidays, weather conditions etc
