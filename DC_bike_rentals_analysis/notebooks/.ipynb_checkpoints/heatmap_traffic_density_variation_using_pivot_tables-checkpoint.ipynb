# %% [markdown]
# ### Pivot Tables

# %% [markdown]
# Use pivot_table to create a pivot table of traffic density over weekdays and/or hours. Identify confounding factors in the dataset (e.g. workdays vs weekdays). Create a notebook with your solution

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../data/bike_dataset_new.csv',parse_dates=['datetime'])

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 17374 2012-12-31 19:00:00       1        0           1        2  10.66
# 17375 2012-12-31 20:00:00       1        0           1        2  10.66
# 17376 2012-12-31 21:00:00       1        0           1        1  10.66
# 17377 2012-12-31 22:00:00       1        0           1        1  10.66
# 17378 2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count  hour  month  \
# 0      14.395        81     0.0000     3.0        13.0     16     0      1
# 1      13.635        80     0.0000     8.0        32.0     40     1      1
# 2      13.635        80     0.0000     5.0        27.0     32     2      1
# 3      14.395        75     0.0000     3.0        10.0     13     3      1
# 4      14.395        75     0.0000     0.0         1.0      1     4      1
# ...       ...       ...        ...     ...         ...    ...   ...    ...
# 17374  12.880        60    11.0014     NaN         NaN    156    19     12
# 17375  12.880        60    11.0014     NaN         NaN    104    20     12
# 17376  12.880        60    11.0014     NaN         NaN     67    21     12
# 17377  13.635        56     8.9981     NaN         NaN     43    22     12
# 17378  13.635        65     8.9981     NaN         NaN     28    23     12
#
#        weekday  day  year part_of_day
# 0            5    1  2011     morning
# 1            5    1  2011     morning
# 2            5    1  2011     morning
# 3            5    1  2011     morning
# 4            5    1  2011     morning
# ...        ...  ...   ...         ...
# 17374        0   31  2012     evening
# 17375        0   31  2012     evening
# 17376        0   31  2012       night
# 17377        0   31  2012       night
# 17378        0   31  2012       night
#
# [17379 rows x 18 columns]

# %%
pivot_table = df.pivot_table(values='count',  #assuming traffic_density is count in the df
                             columns='hour',
                             index=['weekday'],
                             aggfunc="mean")

# %%
pivot_table
# Out:
# hour            0          1          2          3          4          5   \
# weekday
# 0        33.514286  17.942308  11.282828   6.422680   6.173469  20.692308
# 1        27.732673  13.130000   7.564356   5.184783   5.606061  22.653465
# 2        35.509615  16.375000   9.401961   6.040404   5.364583  24.105769
# 3        40.757282  18.077670  10.676471   6.775510   6.310000  26.155340
# 4        52.336538  24.548077  13.288462   7.509804   6.762887  24.451923
# 5        97.114286  68.752381  49.447619  23.295238   9.514286  11.815534
# 6        94.971154  76.096154  58.617647  28.365385  10.617647  12.051020
#
# hour             6           7           8           9   ...          14  \
# weekday                                                  ...
# 0         82.769231  238.144231  394.846154  210.576923  ...  182.759615
# 1         98.480392  274.647059  440.794118  222.892157  ...  157.355769
# 2        102.692308  287.836538  470.759615  233.269231  ...  167.769231
# 3        109.194175  310.213592  499.796117  243.631068  ...  178.524272
# 4         96.317308  265.586538  482.942308  262.192308  ...  226.153846
# 5         25.257143   51.552381  120.238095  189.438095  ...  386.561905
# 6         19.640777   39.800000   87.676190  159.171429  ...  369.219048
#
# hour             15          16          17          18          19  \
# weekday
# 0        192.355769  267.134615  478.951923  454.586538  328.153846
# 1        175.201923  270.750000  517.759615  497.605769  337.346154
# 2        180.846154  264.134615  504.144231  496.737864  358.893204
# 3        196.834951  287.663462  533.086538  503.432692  364.750000
# 4        244.807692  331.028846  506.307692  436.201923  310.990385
# 5        392.152381  373.057143  345.600000  299.759615  246.163462
# 6        364.076190  371.447619  332.771429  276.161905  230.000000
#
# hour             20          21          22          23
# weekday
# 0        228.528846  163.576923  110.500000   63.384615
# 1        238.038462  174.730769  126.115385   74.730769
# 2        255.553398  194.097087  144.106796   82.941748
# 3        271.663462  201.788462  149.644231  101.269231
# 4        223.653846  174.432692  155.307692  118.990385
# 5        187.778846  160.509615  143.038462  119.105769
# 6        176.123810  133.714286  102.780952   67.209524
#
# [7 rows x 24 columns]

# %%
plt.figure(figsize=(10, 6))  

sns.heatmap(pivot_table,
            cmap='Blues', #cmap sets the color map for the heatmap
            cbar=True)  #cabr shows the color bar indicating the color scale

plt.yticks([0,1,2,3,4,5,6], ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'],  rotation=45)
plt.xlabel('Hour',rotation=45)
plt.ylabel('Weekday')
plt.title('Traffic Density Variations by Weekday and Hour')
# Out:
# Text(0.5, 1.0, 'Traffic Density Variations by Weekday and Hour')

# %% [markdown]
# - Above plot shows workdays and peak commuting hours have higher density

# %%
pivot_table_w = df.pivot_table(values='count',  #assuming traffic_density is count in the df
                             columns='weather',
                             index=['season'],
                             aggfunc="mean")

# %%
plt.figure(figsize=(10, 6))  

sns.heatmap(pivot_table_w,
            cmap='Blues', #cmap sets the color map for the heatmap
            cbar=True)  #cabr shows the color bar indicating the color scale
# Out:
# <Axes: xlabel='weather', ylabel='season'>
